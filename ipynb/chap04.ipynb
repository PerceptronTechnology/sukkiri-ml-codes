# %%
import pandas as pd

# %%
data = {
  '松田の労働時間' : [160, 160], # 松田の労働時間列の作成
  '浅木の労働時間' : [161, 175] # 浅木の労働時間列の作成
}

df = pd.DataFrame(data)
df # dfの表示
# Out:
#    松田の労働時間  浅木の労働時間
# 0      160      161
# 1      160      175

# %%
#セルの途中の場合、print関数を
#利用しないと表示できない
print(type(df))

df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (2, 2)

# %%
df.index = ['4月', '5月'] # dfのインデックスを変更
df # 表示
# Out:
#     松田の労働時間  浅木の労働時間
# 4月      160      161
# 5月      160      175

# %%
df.columns = ['松田の労働(h)', '浅木の労働(h)'] # 列名の変更
df # 表示
# Out:
#     松田の労働(h)  浅木の労働(h)
# 4月       160       161
# 5月       160       175

# %%
print(df.index) # インデックスの参照
print(df.columns) # カラムの参照
# Out:
# Index(['4月', '5月'], dtype='object')
# Index(['松田の労働(h)', '浅木の労働(h)'], dtype='object')

# %%
data = [
 [160, 161],
 [160, 175]
    ]

df2 = pd.DataFrame(data, index = ['4月', '5月'], columns =
    ['松田の労働', '浅木の労働'])

# %%
# pandasは別名pdでインポート済み
# KvsT.csvファイルを読み込んで、データフレームに変換
# colabから接続する場合は、以下のコマンドでファイルを読むことは出来ないので変更する
# colabから接続できないため、env環境から接続に変更
folder_name = '/home/user/sukkiri-ml-codes/datafiles'
df = pd.read_csv(f'{folder_name}/KvsT.csv')
# df = pd.read_csv('/home/user/sukkiri-ml-codes/datafiles/KvsT.csv')
# df = pd.read_csv('https://raw.githubusercontent.com/perceptrontechnology/sukkiri-ml-codes/main/datafiles/KvsT.csv')
# df = pd.read_csv('../datafiles/KvsT.csv')
# df = pd.read_csv('KvsT.csv')
# 先頭3行だけ表示
df.head(3)
# Out:
#     身長  体重  年代    派閥
# 0  170  60  10   きのこ
# 1  172  65  20   きのこ
# 2  170  60  30  たけのこ

# %%
#身長列だけを参照
df['身長']
# Out:
# 0     170
# 1     172
# 2     170
# 3     170
# 4     177
# 5     168
# 6     169
# 7     170
# 8     180
# 9     170
# 10    165
# 11    170
# 12    175
# 13    170
# 14    170
# 15    155
# 16    160
# 17    170
# 18    175
# Name: 身長, dtype: int64

# %%
# 抜き出したい列名の文字列リストを作成
col = ['身長', '体重']
# 身長列と体重列のみを抜き出す
df[col]

# %%
type(df['派閥'])

# %%
# 特徴量の列を参照して xに代入
xcol = ['身長', '体重', '年代']
x = df[xcol]
x

# %%
# 正解データ（派閥）を参照して、tに代入
t = df['派閥']
t

# %%
from sklearn import tree

# %%
# モデルの準備（未学習）
model = tree.DecisionTreeClassifier(random_state = 0)
# 学習の実行（x、tは事前に定義済みの特徴量と正解ラベル）
model.fit(x,t)

# %%
# 身長170cm、体重70kg、年齢20代のデータ（新しいデータ）を
# 2次元リストで作成
taro = [[170, 70, 20]]

 # taroがどちらに分類されるか予測
model.predict(taro)

# %%
matsuda=[172,65,20]
asagi=[158,48,20]

new_data=[matsuda,asagi]
model.predict(new_data)

# %%
#正解率の計算
model.score(x, t)

# %%
import pickle

with open('KinokoTakenoko.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
import pickle

with open('KinokoTakenoko.pkl', 'rb') as f:
    model2 = pickle.load(f)

# %%
suzuki = [[180,75,30]]
model2.predict(suzuki)

# %% [markdown]
# # 演習問題

# %%
data = {
    'データベースの試験得点':[70,72,75,80],
    'ネットワークの試験得点':[80,85,79,92]
}
df = pd.DataFrame(data)

# %%
df.index = ['一郎','次郎','三郎','太郎']
df#dfの参照

# %%
df2 = pd.read_csv('ex1.csv')

# %%
df2.index # インデックスの一覧表示

# %%
df2.columns#列名の一覧表示

# %%
col = ['x0','x2']
df2[col]
